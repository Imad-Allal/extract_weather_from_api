# %%
import folium
import pandas as pd

# %%
dataSet = pd.read_csv('./transformed_data.csv')
position = dataSet[[ "city", "latitude","longitude", "temperature"]]

# %%
position
# Out:
#           city  latitude  longitude  temperature
# 0      Algiers   36.6875     3.1250         24.7
# 1       Annaba   36.8750     7.7500         23.3
# 2        Batna   35.5625     6.2500         20.0
# 3  Tamanrasset   22.8000     5.5000         33.5
# 4      Tlemcen   34.8750    -1.3125         26.4

# %%
map = folium.Map(location=[position.latitude.mean(), position.longitude.mean()], zoom_start=5)

# %%
for index, location_info in position.iterrows():
    folium.Marker([location_info["latitude"], location_info["longitude"]], popup=location_info["temperature"]).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_54f62b0d4b80babd1602a33a4aa2dcdf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_54f62b0d4b80babd1602a33a4aa2dcdf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_54f62b0d4b80babd1602a33a4aa2dcdf = L.map(
#                 &quot;map_54f62b0d4b80babd1602a33a4aa2dcdf&quot;,
#                 {
#                     center: [33.36, 4.2625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_94bff903bc9dd5a0319cfe7f63a74ca9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_54f62b0d4b80babd1602a33a4aa2dcdf);
#
#
#             var marker_daaa9b7e8f98a5581b7e2f2f5b65449a = L.marker(
#                 [36.6875, 3.125],
#                 {}
#             ).addTo(map_54f62b0d4b80babd1602a33a4aa2dcdf);
#
#
#         var popup_f88d3d51d750e23313524c04cbfb3cc8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_14a20017592114c1be09bd769c0659b5 = $(`&lt;div id=&quot;html_14a20017592114c1be09bd769c0659b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;24.7&lt;/div&gt;`)[0];
#                 popup_f88d3d51d750e23313524c04cbfb3cc8.setContent(html_14a20017592114c1be09bd769c0659b5);
#
#
#
#         marker_daaa9b7e8f98a5581b7e2f2f5b65449a.bindPopup(popup_f88d3d51d750e23313524c04cbfb3cc8)
#         ;
#
#
#
#
#             var marker_469eb3c426863a60402144456dc99b21 = L.marker(
#                 [36.875, 7.75],
#                 {}
#             ).addTo(map_54f62b0d4b80babd1602a33a4aa2dcdf);
#
#
#         var popup_7ada30bce40ec6c96b9e1a645f08e150 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_332b44b80ea92bdf078b5f67ea24fce7 = $(`&lt;div id=&quot;html_332b44b80ea92bdf078b5f67ea24fce7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;23.3&lt;/div&gt;`)[0];
#                 popup_7ada30bce40ec6c96b9e1a645f08e150.setContent(html_332b44b80ea92bdf078b5f67ea24fce7);
#
#
#
#         marker_469eb3c426863a60402144456dc99b21.bindPopup(popup_7ada30bce40ec6c96b9e1a645f08e150)
#         ;
#
#
#
#
#             var marker_07751880e7a663899312caf72dea3726 = L.marker(
#                 [35.5625, 6.25],
#                 {}
#             ).addTo(map_54f62b0d4b80babd1602a33a4aa2dcdf);
#
#
#         var popup_714692f4f4692dda4ae188831fe21e32 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d6ea4ae04c98608fbfb764ff57922557 = $(`&lt;div id=&quot;html_d6ea4ae04c98608fbfb764ff57922557&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;20.0&lt;/div&gt;`)[0];
#                 popup_714692f4f4692dda4ae188831fe21e32.setContent(html_d6ea4ae04c98608fbfb764ff57922557);
#
#
#
#         marker_07751880e7a663899312caf72dea3726.bindPopup(popup_714692f4f4692dda4ae188831fe21e32)
#         ;
#
#
#
#
#             var marker_1e89afdc2364de32b0bde75291f2dc49 = L.marker(
#                 [22.8, 5.5],
#                 {}
#             ).addTo(map_54f62b0d4b80babd1602a33a4aa2dcdf);
#
#
#         var popup_870ec9b6ff1dfee204f7de7273f865cc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6d1394e356d944c0dd54fc618a732fcd = $(`&lt;div id=&quot;html_6d1394e356d944c0dd54fc618a732fcd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;33.5&lt;/div&gt;`)[0];
#                 popup_870ec9b6ff1dfee204f7de7273f865cc.setContent(html_6d1394e356d944c0dd54fc618a732fcd);
#
#
#
#         marker_1e89afdc2364de32b0bde75291f2dc49.bindPopup(popup_870ec9b6ff1dfee204f7de7273f865cc)
#         ;
#
#
#
#
#             var marker_da92e0804943107fce7c7faa12db7661 = L.marker(
#                 [34.875, -1.3125],
#                 {}
#             ).addTo(map_54f62b0d4b80babd1602a33a4aa2dcdf);
#
#
#         var popup_7f4f8ab32ffef0f56e4246ddf0e77218 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7243003955155300c77c79d782ca53b9 = $(`&lt;div id=&quot;html_7243003955155300c77c79d782ca53b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;26.4&lt;/div&gt;`)[0];
#                 popup_7f4f8ab32ffef0f56e4246ddf0e77218.setContent(html_7243003955155300c77c79d782ca53b9);
#
#
#
#         marker_da92e0804943107fce7c7faa12db7661.bindPopup(popup_7f4f8ab32ffef0f56e4246ddf0e77218)
#         ;
#
#
#
#
#             var marker_0da0244aae4706abe3225745686c6cfa = L.marker(
#                 [36.6875, 3.125],
#                 {}
#             ).addTo(map_54f62b0d4b80babd1602a33a4aa2dcdf);
#
#
#         var popup_94
